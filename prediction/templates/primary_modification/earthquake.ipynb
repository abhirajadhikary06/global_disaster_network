# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
script_dir = os.path.dirname(os.path.abspath(os.getcwd()))
file_path = os.path.join(script_dir, "raw_datasets", "earthquake.xlsx")
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2000-0023-BGD       No    nat-geo-ear-gro        Natural       Geophysical
# 1  2000-0033-CHN       No    nat-geo-ear-gro        Natural       Geophysical
# 2  2000-0036-CHN       No    nat-geo-ear-gro        Natural       Geophysical
# 3  2000-0041-CHN       No    nat-geo-ear-gro        Natural       Geophysical
# 4  2000-0051-IRN       No    nat-geo-ear-gro        Natural       Geophysical
#
#   Disaster Type Disaster Subtype     External IDs  Event Name  ISO  ...  \
# 0    Earthquake  Ground movement  USGS:usp0009khm         NaN  BGD  ...
# 1    Earthquake  Ground movement  USGS:usp0009m4u         NaN  CHN  ...
# 2    Earthquake  Ground movement  USGS:usp0009mq6         NaN  CHN  ...
# 3    Earthquake  Ground movement  USGS:usp0009m1j         NaN  CHN  ...
# 4    Earthquake  Ground movement  USGS:usp0009mz6         NaN  IRN  ...
#
# ...

# %%
df.rename(columns={df.columns[0]: 'Year'}, inplace=True)

# %%
required_columns = ['Year', 'Disaster Type', 'Country', 'Location', 'Total Affected', 'Magnitude']
df = df[required_columns]

# %%
df.isnull().sum()
# Out:
# Year               0
# Disaster Type      0
# Country            0
# Location           5
# Total Affected    20
# Magnitude          2
# dtype: int64

# %%
df['Location'].fillna(df['Location'].mode()[0], inplace=True)
df['Total Affected'].fillna(df['Total Affected'].mode()[0], inplace=True)
df['Magnitude'].fillna(df['Magnitude'].mode()[0], inplace=True)
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_58556/77384327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Location'].fillna(df['Location'].mode()[0], inplace=True)
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_58556/77384327.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
df.isnull().sum()
# Out:
# Year              0
# Disaster Type     0
# Country           0
# Location          0
# Total Affected    0
# Magnitude         0
# dtype: int64

# %%
df
# Out:
#               Year Disaster Type                     Country  \
# 0    2000-0023-BGD    Earthquake                  Bangladesh
# 1    2000-0033-CHN    Earthquake                       China
# 2    2000-0036-CHN    Earthquake                       China
# 3    2000-0041-CHN    Earthquake                       China
# 4    2000-0051-IRN    Earthquake  Iran (Islamic Republic of)
# ..             ...           ...                         ...
# 662  2024-0848-CUB    Earthquake                        Cuba
# 663  2024-0911-VUT    Earthquake                     Vanuatu
# 664  2025-0004-CHN    Earthquake                       China
# 665  2025-0004-NPL    Earthquake                       Nepal
# 666  2025-0018-ETH    Earthquake                    Ethiopia
#
#                                               Location  Total Affected  \
# 0    Maheshkhali area (Cox's Bazar district, Chitta...          1000.0
# 1    Yongren Xian, Yao'an Xian, Nanhua Xian, Dayao ...       1855007.0
# ...

# %%
df['Year'] = df['Year'].astype(str).str[:4]
df['Location'] = df['Location'].str.split(',').str[0]
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_58556/4287316212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].astype(str).str[:4]
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_58556/4287316212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Location'] = df['Location'].str.split(',').str[0]

# %%
df
# Out:
#      Year Disaster Type                     Country  \
# 0    2000    Earthquake                  Bangladesh
# 1    2000    Earthquake                       China
# 2    2000    Earthquake                       China
# 3    2000    Earthquake                       China
# 4    2000    Earthquake  Iran (Islamic Republic of)
# ..    ...           ...                         ...
# 662  2024    Earthquake                        Cuba
# 663  2024    Earthquake                     Vanuatu
# 664  2025    Earthquake                       China
# 665  2025    Earthquake                       Nepal
# 666  2025    Earthquake                    Ethiopia
#
#                                          Location  Total Affected  Magnitude
# 0          Maheshkhali area (Cox's Bazar district          1000.0        4.3
# 1                                    Yongren Xian       1855007.0        5.9
# 2     Mile Xian area (Honghe Hani and Yi district         10302.0        4.9
# ...

# %%
df.to_csv("earthquake_cleaned.csv", index=False)

# %%
df.isnull().sum()
# Out:
# Year              0
# Disaster Type     0
# Country           0
# Location          0
# Total Affected    0
# Magnitude         0
# dtype: int64
