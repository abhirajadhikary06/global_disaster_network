# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
script_dir = os.path.dirname(os.path.abspath(os.getcwd()))
file_path = os.path.join(script_dir, "raw_datasets", "flood.xlsx")
df = pd.read_excel(file_path)

# %%
df.shape
# Out:
# (4129, 46)

# %%
df
# Out:
#              DisNo. Historic Classification Key Disaster Group  \
# 0     2000-0002-AGO       No    nat-hyd-flo-riv        Natural
# 1     2000-0012-MOZ       No    nat-hyd-flo-riv        Natural
# 2     2000-0019-BRA       No    nat-hyd-flo-riv        Natural
# 3     2000-0038-PHL       No    nat-hyd-flo-fla        Natural
# 4     2000-0043-ZAF       No    nat-hyd-flo-riv        Natural
# ...             ...      ...                ...            ...
# 4124  2025-0116-MYS       No    nat-hyd-flo-flo        Natural
# 4125  2025-0127-AFG       No    nat-hyd-flo-fla        Natural
# 4126  2025-0128-MDG       No    nat-hyd-flo-flo        Natural
# 4127  2025-0138-PER       No    nat-hyd-flo-flo        Natural
# 4128  2025-0150-IDN       No    nat-hyd-flo-flo        Natural
#
#      Disaster Subgroup Disaster Type Disaster Subtype          External IDs  \
# 0         Hydrological         Flood   Riverine flood                   NaN
# 1         Hydrological         Flood   Riverine flood                   NaN
# 2         Hydrological         Flood   Riverine flood                   NaN
# 3         Hydrological         Flood      Flash flood                   NaN
# 4         Hydrological         Flood   Riverine flood                   NaN
# ...                ...           ...              ...                   ...
# 4124      Hydrological         Flood  Flood (General)                   NaN
# 4125      Hydrological         Flood      Flash flood                   NaN
# 4126      Hydrological         Flood  Flood (General)                   NaN
# 4127      Hydrological         Flood  Flood (General)  GLIDE:FL-2025-000022
# 4128      Hydrological         Flood  Flood (General)                   NaN
#
#      Event Name  ISO  ... Reconstruction Costs ('000 US$)  \
# 0           NaN  AGO  ...                             NaN
# 1           NaN  MOZ  ...                             NaN
# 2           NaN  BRA  ...                             NaN
# 3           NaN  PHL  ...                             NaN
# 4           NaN  ZAF  ...                             NaN
# ...         ...  ...  ...                             ...
# 4124        NaN  MYS  ...                             NaN
# 4125        NaN  AFG  ...                             NaN
# 4126        NaN  MDG  ...                             NaN
# 4127        NaN  PER  ...                             NaN
# 4128        NaN  IDN  ...                             NaN
#
#      Reconstruction Costs, Adjusted ('000 US$) Insured Damage ('000 US$)  \
# 0                                          NaN                       NaN
# 1                                          NaN                    1500.0
# 2                                          NaN                       NaN
# 3                                          NaN                       NaN
# 4                                          NaN                   50000.0
# ...                                        ...                       ...
# 4124                                       NaN                       NaN
# 4125                                       NaN                       NaN
# 4126                                       NaN                       NaN
# 4127                                       NaN                       NaN
# 4128                                       NaN                       NaN
#
#      Insured Damage, Adjusted ('000 US$) Total Damage ('000 US$)  \
# 0                                    NaN                 10000.0
# 1                                 2654.0                419200.0
# 2                                    NaN                     NaN
# 3                                    NaN                  4080.0
# 4                                88473.0                160000.0
# ...                                  ...                     ...
# 4124                                 NaN                     NaN
# 4125                                 NaN                     NaN
# 4126                                 NaN                     NaN
# 4127                                 NaN                     NaN
# 4128                                 NaN                     NaN
#
#      Total Damage, Adjusted ('000 US$)        CPI  \
# 0                              17695.0  56.514291
# 1                             741759.0  56.514291
# 2                                  NaN  56.514291
# 3                               7219.0  56.514291
# 4                             283114.0  56.514291
# ...                                ...        ...
# 4124                               NaN        NaN
# 4125                               NaN        NaN
# 4126                               NaN        NaN
# 4127                               NaN        NaN
# 4128                               NaN        NaN
#
#                                             Admin Units  Entry Date  \
# 0     [{"adm2_code":4214,"adm2_name":"Baia Farta"},{...  2005-02-03
# 1     [{"adm1_code":2114,"adm1_name":"Inhambane"},{"...  2005-09-16
# 2     [{"adm2_code":8467,"adm2_name":"Pirangucu"},{"...  2005-07-08
# 3     [{"adm2_code":24275,"adm2_name":"Agusan Del No...  2004-10-27
# 4     [{"adm1_code":2708,"adm1_name":"Gauteng"},{"ad...  2005-09-16
# ...                                                 ...         ...
# 4124                                                NaN  2025-02-21
# 4125                                                NaN  2025-02-26
# 4126                                                NaN  2025-02-26
# 4127                                                NaN  2025-02-27
# 4128                                                NaN  2025-03-04
#
#       Last Update
# 0      2023-09-25
# 1      2023-09-25
# 2      2023-09-25
# 3      2023-09-25
# 4      2023-09-25
# ...           ...
# 4124   2025-02-28
# 4125   2025-02-27
# 4126   2025-02-28
# 4127   2025-03-04
# 4128   2025-03-11
#
# [4129 rows x 46 columns]

# %%
df.rename(columns={df.columns[0]: 'Year'}, inplace=True)
required_columns = ['Year', 'Disaster Type', 'Country', 'Location', 'Total Affected', 'Magnitude']
df = df[required_columns]

# %%
df
# Out:
#                Year Disaster Type       Country  \
# 0     2000-0002-AGO         Flood        Angola
# 1     2000-0012-MOZ         Flood    Mozambique
# 2     2000-0019-BRA         Flood        Brazil
# 3     2000-0038-PHL         Flood   Philippines
# 4     2000-0043-ZAF         Flood  South Africa
# ...             ...           ...           ...
# 4124  2025-0116-MYS         Flood      Malaysia
# 4125  2025-0127-AFG         Flood   Afghanistan
# 4126  2025-0128-MDG         Flood    Madagascar
# 4127  2025-0138-PER         Flood          Peru
# 4128  2025-0150-IDN         Flood     Indonesia
#
#                                                Location  Total Affected  \
# 0     Dombre Grande village (Baia Farta district, Be...         70000.0
# 1     Matutuine, Manhica, Magude, Marracuene distric...       4500000.0
# 2     Rio de Janeiro city (Rio de Janeiro district, ...         70000.0
# 3     Agusan del Sur, Agusan del Norte, Surigao del ...        153885.0
# 4          Mpumalanga, KwaZulu-Natal, Gauteng provinces           200.0
# ...                                                 ...             ...
# 4124                  Pahang and Negeri Sembilan states           251.0
# 4125  Farah region; Pushtkoh district; Kandahar prov...            44.0
# 4126                                  Analamanga region             NaN
# 4127                                       Huancavelica         57000.0
# 4128  Bogor regency (West Java province); Sukabumi R...         78006.0
#
#       Magnitude
# 0       47000.0
# 1        1980.0
# 2      350000.0
# 3       16700.0
# 4           NaN
# ...         ...
# 4124        NaN
# 4125        NaN
# 4126        NaN
# 4127        NaN
# 4128        NaN
#
# [4129 rows x 6 columns]

# %%
df['Year'] = df['Year'].astype(str).str[:4]
df['Location'] = df['Location'].str.split(',').str[0]
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_64709/4287316212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].astype(str).str[:4]
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_64709/4287316212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Location'] = df['Location'].str.split(',').str[0]

# %%
df
# Out:
#       Year Disaster Type       Country  \
# 0     2000         Flood        Angola
# 1     2000         Flood    Mozambique
# 2     2000         Flood        Brazil
# 3     2000         Flood   Philippines
# 4     2000         Flood  South Africa
# ...    ...           ...           ...
# 4124  2025         Flood      Malaysia
# 4125  2025         Flood   Afghanistan
# 4126  2025         Flood    Madagascar
# 4127  2025         Flood          Peru
# 4128  2025         Flood     Indonesia
#
#                                                Location  Total Affected  \
# 0            Dombre Grande village (Baia Farta district         70000.0
# 1                                             Matutuine       4500000.0
# 2          Rio de Janeiro city (Rio de Janeiro district         70000.0
# 3                                        Agusan del Sur        153885.0
# 4                                            Mpumalanga           200.0
# ...                                                 ...             ...
# 4124                  Pahang and Negeri Sembilan states           251.0
# 4125  Farah region; Pushtkoh district; Kandahar prov...            44.0
# 4126                                  Analamanga region             NaN
# 4127                                       Huancavelica         57000.0
# 4128  Bogor regency (West Java province); Sukabumi R...         78006.0
#
#       Magnitude
# 0       47000.0
# 1        1980.0
# 2      350000.0
# 3       16700.0
# 4           NaN
# ...         ...
# 4124        NaN
# 4125        NaN
# 4126        NaN
# 4127        NaN
# 4128        NaN
#
# [4129 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Year                 0
# Disaster Type        0
# Country              0
# Location            23
# Total Affected     419
# Magnitude         2734
# dtype: int64

# %%
sns.violinplot(x = 'Magnitude', data = df)
# Out:
# <Axes: xlabel='Magnitude'>

# %%
df
# Out:
#       Year Disaster Type       Country  \
# 0     2000         Flood        Angola
# 1     2000         Flood    Mozambique
# 2     2000         Flood        Brazil
# 3     2000         Flood   Philippines
# 4     2000         Flood  South Africa
# ...    ...           ...           ...
# 4124  2025         Flood      Malaysia
# 4125  2025         Flood   Afghanistan
# 4126  2025         Flood    Madagascar
# 4127  2025         Flood          Peru
# 4128  2025         Flood     Indonesia
#
#                                                Location  Total Affected  \
# 0            Dombre Grande village (Baia Farta district         70000.0
# 1                                             Matutuine       4500000.0
# 2          Rio de Janeiro city (Rio de Janeiro district         70000.0
# 3                                        Agusan del Sur        153885.0
# 4                                            Mpumalanga           200.0
# ...                                                 ...             ...
# 4124                  Pahang and Negeri Sembilan states           251.0
# 4125  Farah region; Pushtkoh district; Kandahar prov...            44.0
# 4126                                  Analamanga region             NaN
# 4127                                       Huancavelica         57000.0
# 4128  Bogor regency (West Java province); Sukabumi R...         78006.0
#
#       Magnitude
# 0       47000.0
# 1        1980.0
# 2      350000.0
# 3       16700.0
# 4           NaN
# ...         ...
# 4124        NaN
# 4125        NaN
# 4126        NaN
# 4127        NaN
# 4128        NaN
#
# [4129 rows x 6 columns]

# %%
df_min = df['Magnitude'].min()

df['Magnitude'] = df['Magnitude'].apply(
    lambda x: round(np.random.uniform(df_min, 100000), 1) if pd.isna(x) else x
)
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_64709/773988139.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Magnitude'] = df['Magnitude'].apply(

# %%
df.isnull().sum()
# Out:
# Year                0
# Disaster Type       0
# Country             0
# Location           23
# Total Affected    419
# Magnitude           0
# dtype: int64

# %%
df['Location'].fillna(df['Location'].mode()[0], inplace=True)
df['Total Affected'].fillna(df['Total Affected'].mode()[0], inplace=True)
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_64709/4170441267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Location'].fillna(df['Location'].mode()[0], inplace=True)
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_64709/4170441267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Location'].fillna(df['Location'].mode()[0], inplace=True)
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_64709/4170441267.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Total Affected'].fillna(df['Total Affected'].mode()[0], inplace=True)
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_64709/4170441267.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Affected'].fillna(df['Total Affected'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Year              0
# Disaster Type     0
# Country           0
# Location          0
# Total Affected    0
# Magnitude         0
# dtype: int64

# %%
df.head()
# Out:
#    Year Disaster Type       Country  \
# 0  2000         Flood        Angola
# 1  2000         Flood    Mozambique
# 2  2000         Flood        Brazil
# 3  2000         Flood   Philippines
# 4  2000         Flood  South Africa
#
#                                        Location  Total Affected  Magnitude
# 0    Dombre Grande village (Baia Farta district         70000.0    47000.0
# 1                                     Matutuine       4500000.0     1980.0
# 2  Rio de Janeiro city (Rio de Janeiro district         70000.0   350000.0
# 3                                Agusan del Sur        153885.0    16700.0
# 4                                    Mpumalanga           200.0    40476.7

# %%
df.to_csv("flood_cleaned.csv", index=False)
