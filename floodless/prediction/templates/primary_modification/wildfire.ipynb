# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
script_dir = os.path.dirname(os.path.abspath(os.getcwd()))
file_path = os.path.join(script_dir, "raw_datasets", "wildfire.xlsx")
df = pd.read_excel(file_path)

# %%
df
# Out:
#             DisNo. Historic Classification Key Disaster Group  \
# 0    2000-0017-ZAF       No    nat-cli-wil-lan        Natural
# 1    2000-0104-ETH       No    nat-cli-wil-for        Natural
# 2    2000-0117-IDN       No    nat-cli-wil-for        Natural
# 3    2000-0128-USA       No    nat-cli-wil-for        Natural
# 4    2000-0188-TUR       No    nat-cli-wil-for        Natural
# ..             ...      ...                ...            ...
# 314  2024-0897-USA       No    nat-cli-wil-wil        Natural
# 315  2025-0008-USA       No    nat-cli-wil-wil        Natural
# 316  2025-0022-ARG       No    nat-cli-wil-wil        Natural
# 317  2025-0047-AUS       No    nat-cli-wil-wil        Natural
# 318  2025-0135-JPN       No    nat-cli-wil-for        Natural
#
#     Disaster Subgroup Disaster Type                  Disaster Subtype  \
# 0      Climatological      Wildfire  Land fire (Brush, Bush, Pasture)
# 1      Climatological      Wildfire                       Forest fire
# 2      Climatological      Wildfire                       Forest fire
# 3      Climatological      Wildfire                       Forest fire
# 4      Climatological      Wildfire                       Forest fire
# ..                ...           ...                               ...
# 314    Climatological      Wildfire                Wildfire (General)
# 315    Climatological      Wildfire                Wildfire (General)
# 316    Climatological      Wildfire                Wildfire (General)
# 317    Climatological      Wildfire                Wildfire (General)
# 318    Climatological      Wildfire                       Forest fire
#
#     External IDs                                         Event Name  ISO  ...  \
# 0            NaN                                                NaN  ZAF  ...
# 1            NaN                                                NaN  ETH  ...
# 2            NaN                                                NaN  IDN  ...
# 3            NaN                                                NaN  USA  ...
# 4            NaN                                                NaN  TUR  ...
# ..           ...                                                ...  ...  ...
# 314          NaN                                         'Franklin'  USA  ...
# 315          NaN  'Palisades', 'Eaton', 'Sunset', 'Kenneth', 'Hu...  USA  ...
# 316          NaN                   'Confluencia' and 'Epuyén' Fires  ARG  ...
# 317          NaN                                                NaN  AUS  ...
# 318          NaN                                                NaN  JPN  ...
#
#     Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# 0                               NaN                                       NaN
# 1                               NaN                                       NaN
# 2                               NaN                                       NaN
# 3                               NaN                                       NaN
# 4                               NaN                                       NaN
# ..                              ...                                       ...
# 314                             NaN                                       NaN
# 315                             NaN                                       NaN
# 316                             NaN                                       NaN
# 317                             NaN                                       NaN
# 318                             NaN                                       NaN
#
#     Insured Damage ('000 US$) Insured Damage, Adjusted ('000 US$)  \
# 0                      8000.0                             14156.0
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
# ..                        ...                                 ...
# 314                       NaN                                 NaN
# 315                       NaN                                 NaN
# 316                       NaN                                 NaN
# 317                       NaN                                 NaN
# 318                       NaN                                 NaN
#
#     Total Damage ('000 US$) Total Damage, Adjusted ('000 US$)        CPI  \
# 0                   10000.0                           17695.0  56.514291
# 1                       NaN                               NaN  56.514291
# 2                       NaN                               NaN  56.514291
# 3                       NaN                               NaN  56.514291
# 4                       NaN                               NaN  56.514291
# ..                      ...                               ...        ...
# 314                     NaN                               NaN        NaN
# 315                     NaN                               NaN        NaN
# 316                     NaN                               NaN        NaN
# 317                     NaN                               NaN        NaN
# 318                     NaN                               NaN        NaN
#
#                                            Admin Units  Entry Date  \
# 0    [{"adm2_code":77317,"adm2_name":"City of Cape ...  2005-07-08
# 1    [{"adm2_code":40838,"adm2_name":"Sidama"},{"ad...  2003-07-01
# 2    [{"adm1_code":1522,"adm1_name":"Kalimantan Bar...  2003-07-01
# 3    [{"adm2_code":28998,"adm2_name":"Alachua"},{"a...  2003-07-01
# 4    [{"adm1_code":3028,"adm1_name":"Balikesir"},{"...  2003-07-01
# ..                                                 ...         ...
# 314                                                NaN  2024-12-11
# 315                                                NaN  2025-01-09
# 316                                                NaN  2025-01-17
# 317                                                NaN  2025-01-29
# 318                                                NaN  2025-02-27
#
#      Last Update
# 0     2023-09-25
# 1     2023-09-25
# 2     2023-09-25
# 3     2023-09-25
# 4     2023-09-25
# ..           ...
# 314   2025-03-18
# 315   2025-02-12
# 316   2025-02-17
# 317   2025-02-13
# 318   2025-03-18
#
# [319 rows x 46 columns]

# %%
df.rename(columns={df.columns[0]: 'Year'}, inplace=True)
required_columns = ['Year', 'Disaster Type', 'Country', 'Location', 'Total Affected', 'Magnitude']
df = df[required_columns]
df['Year'] = df['Year'].astype(str).str[:4]
df['Location'] = df['Location'].str.split(',').str[0]
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_3808/1703866343.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].astype(str).str[:4]
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_3808/1703866343.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Location'] = df['Location'].str.split(',').str[0]

# %%
df
# Out:
#      Year Disaster Type                   Country  \
# 0    2000      Wildfire              South Africa
# 1    2000      Wildfire                  Ethiopia
# 2    2000      Wildfire                 Indonesia
# 3    2000      Wildfire  United States of America
# 4    2000      Wildfire                   Türkiye
# ..    ...           ...                       ...
# 314  2024      Wildfire  United States of America
# 315  2025      Wildfire  United States of America
# 316  2025      Wildfire                 Argentina
# 317  2025      Wildfire                 Australia
# 318  2025      Wildfire                     Japan
#
#                                               Location  Total Affected  \
# 0    City of Capta Town Metropolitan Municipality (...          1250.0
# 1                                                 Bale             5.0
# 2                         Riau province (Sumatra Isl.)             NaN
# 3                                          Gainesville           600.0
# 4                                                Bursa           350.0
# ..                                                 ...             ...
# 314                                   Near Malibu city           150.0
# 315  Los Angeles County (northern of Los Angeles) a...             NaN
# 316                   Epuyén town (Cushamen Department          1500.0
# 317                             Dimbola and Wail towns           260.0
# 318                                            Ofunato           252.0
#
#      Magnitude
# 0          NaN
# 1        970.0
# 2          NaN
# 3        113.0
# 4          8.0
# ..         ...
# 314        NaN
# 315        NaN
# 316        NaN
# 317        NaN
# 318        NaN
#
# [319 rows x 6 columns]

# %%
df.shape
# Out:
# (319, 6)

# %%
df.isnull().sum()
# Out:
# Year                0
# Disaster Type       0
# Country             0
# Location            1
# Total Affected     79
# Magnitude         231
# dtype: int64

# %%
sns.violinplot(x = 'Magnitude', data = df)
# Out:
# <Axes: xlabel='Magnitude'>

# %%
df['Magnitude'] = df['Magnitude'].apply(
    lambda x : round(np.random.uniform(df['Magnitude'].min(), 200000), 1) if pd.isna(x) else x
)
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_3808/3931042391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Magnitude'] = df['Magnitude'].apply(

# %%
df['Total Affected'].fillna(df['Total Affected'].mode()[0], inplace=True)
df['Location'].fillna(df['Location'].mode()[0], inplace=True)
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_3808/1995198506.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Total Affected'].fillna(df['Total Affected'].mode()[0], inplace=True)
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_3808/1995198506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Affected'].fillna(df['Total Affected'].mode()[0], inplace=True)
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_3808/1995198506.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Location'].fillna(df['Location'].mode()[0], inplace=True)
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_3808/1995198506.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Location'].fillna(df['Location'].mode()[0], inplace=True)

# %%
df.to_csv("wildfire_cleaned.csv", index=False)
